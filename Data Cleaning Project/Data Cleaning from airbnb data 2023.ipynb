# %% [markdown]
# ### Importing pandas

# %%
import pandas as pd

# %% [markdown]
# ### Read the CSV file into a pandas DataFrame

# %%
data = pd.read_csv('listings.csv')

# %% [markdown]
# ### Explore the dataset

# %%
print(data.head())  # Print the first few rows of the DataFrame
print(data.info())  # Get information about the DataFrame
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   90676   https://www.airbnb.com/rooms/90676  20230328184402   2023-03-28
# 1  543140  https://www.airbnb.com/rooms/543140  20230328184402   2023-03-28
# 2  591101  https://www.airbnb.com/rooms/591101  20230328184402   2023-03-28
# 3  923248  https://www.airbnb.com/rooms/923248  20230328184402   2023-03-28
# 4  927867  https://www.airbnb.com/rooms/927867  20230328184402   2023-03-28
#
#         source                                              name  \
# 0  city scrape                  Short North - Italianate Cottage
# 1  city scrape                Private queen bedroom 1 - N.Campus
# 2  city scrape                    Bellows Studio Loft  Apartment
# 3  city scrape  1 Single Bed in a Shared Coed Dorm at the Hostel
# 4  city scrape                   Full Private Room at the Hostel
#
#                                          description  \
# 0  Just steps from High Street and all the action...
# 1  Private, second-floor queen bed with desk, ple...
# 2  Famous American artist George Bellows home wit...
# 3  This is a shared dormitory room of up to 5 peo...
# 4  The Wayfaring Buckeye Hostel is a social place...
#
#                                neighborhood_overview  \
# 0  The Short North Italianate Cottage is located ...
# 1                   We are close to a lot of things!
# 2  A historic neighborhood of beautiful victorian...
# 3  We are located in the vibrant University Distr...
# 4  We are located in the vibrant University Distr...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/950e43cd-53f3...   483306  ...
# 1  https://a0.muscache.com/pictures/e720cdf0-e36b...  2350409  ...
# 2  https://a0.muscache.com/pictures/083ed5ee-7b8d...  2889677  ...
# 3  https://a0.muscache.com/pictures/29aabf51-4e6f...  4965048  ...
# 4  https://a0.muscache.com/pictures/08033ebe-286c...  4965048  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.88                   4.93                4.78
# 1                        4.89                   4.77                4.80
# 2                        4.91                   4.89                4.88
# 3                        4.89                   4.69                4.85
# 4                        4.90                   4.72                4.70
#
#      license instant_bookable calculated_host_listings_count  \
# 0  2022-2475                f                              3
# 1  2019-1344                f                              3
# 2  2019-1230                f                              1
# 3  2019-1314                f                              8
# 4  2019-1314                f                              8
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           3
# 1                                           0
# 2                                           0
# 3                                           2
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            3
# 2                                            1
# 3                                            4
# 4                                            4
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              4.64
# 1                                           0              0.96
# 2                                           0              2.16
# 3                                           2              2.49
# 4                                           2              0.59
#
# [5 rows x 75 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2344 entries, 0 to 2343
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            2344 non-null   int64
#  1   listing_url                                   2344 non-null   object
#  2   scrape_id                                     2344 non-null   int64
#  3   last_scraped                                  2344 non-null   object
#  4   source                                        2344 non-null   object
#  5   name                                          2344 non-null   object
#  6   description                                   2338 non-null   object
#  7   neighborhood_overview                         1659 non-null   object
#  8   picture_url                                   2344 non-null   object
#  9   host_id                                       2344 non-null   int64
#  10  host_url                                      2344 non-null   object
#  11  host_name                                     2344 non-null   object
#  12  host_since                                    2344 non-null   object
#  13  host_location                                 1951 non-null   object
#  14  host_about                                    1498 non-null   object
#  15  host_response_time                            2218 non-null   object
#  16  host_response_rate                            2218 non-null   object
#  17  host_acceptance_rate                          2253 non-null   object
#  18  host_is_superhost                             2344 non-null   object
#  19  host_thumbnail_url                            2344 non-null   object
#  20  host_picture_url                              2344 non-null   object
#  21  host_neighbourhood                            2015 non-null   object
#  22  host_listings_count                           2344 non-null   int64
#  23  host_total_listings_count                     2344 non-null   int64
#  24  host_verifications                            2344 non-null   object
#  25  host_has_profile_pic                          2344 non-null   object
#  26  host_identity_verified                        2344 non-null   object
#  27  neighbourhood                                 1659 non-null   object
#  28  neighbourhood_cleansed                        2344 non-null   object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      2344 non-null   float64
#  31  longitude                                     2344 non-null   float64
#  32  property_type                                 2344 non-null   object
#  33  room_type                                     2344 non-null   object
#  34  accommodates                                  2344 non-null   int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                2344 non-null   object
#  37  bedrooms                                      2280 non-null   float64
#  38  beds                                          2329 non-null   float64
#  39  amenities                                     2344 non-null   object
#  40  price                                         2344 non-null   object
#  41  minimum_nights                                2344 non-null   int64
#  42  maximum_nights                                2344 non-null   int64
#  43  minimum_minimum_nights                        2344 non-null   int64
#  44  maximum_minimum_nights                        2344 non-null   int64
#  45  minimum_maximum_nights                        2344 non-null   int64
#  46  maximum_maximum_nights                        2344 non-null   int64
#  47  minimum_nights_avg_ntm                        2344 non-null   float64
#  48  maximum_nights_avg_ntm                        2344 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              2344 non-null   object
#  51  availability_30                               2344 non-null   int64
#  52  availability_60                               2344 non-null   int64
#  53  availability_90                               2344 non-null   int64
#  54  availability_365                              2344 non-null   int64
#  55  calendar_last_scraped                         2344 non-null   object
#  56  number_of_reviews                             2344 non-null   int64
#  57  number_of_reviews_ltm                         2344 non-null   int64
#  58  number_of_reviews_l30d                        2344 non-null   int64
#  59  first_review                                  2052 non-null   object
#  60  last_review                                   2052 non-null   object
#  61  review_scores_rating                          2052 non-null   float64
#  62  review_scores_accuracy                        2052 non-null   float64
#  63  review_scores_cleanliness                     2052 non-null   float64
#  64  review_scores_checkin                         2052 non-null   float64
#  65  review_scores_communication                   2052 non-null   float64
#  66  review_scores_location                        2052 non-null   float64
#  67  review_scores_value                           2052 non-null   float64
#  68  license                                       2075 non-null   object
#  69  instant_bookable                              2344 non-null   object
#  70  calculated_host_listings_count                2344 non-null   int64
#  71  calculated_host_listings_count_entire_homes   2344 non-null   int64
#  72  calculated_host_listings_count_private_rooms  2344 non-null   int64
#  73  calculated_host_listings_count_shared_rooms   2344 non-null   int64
#  74  reviews_per_month                             2052 non-null   float64
# dtypes: float64(17), int64(23), object(35)
# memory usage: 1.3+ MB
# None

# %% [markdown]
# ### Handle missing values

# %%
data.dropna(subset=['price'], inplace=True)  # Drop rows with missing price values

# %% [markdown]
# ### Convert data types

# %%
data['price'] = data['price'].str.replace('$', '').str.replace(',', '').astype(float)  # Convert price to numeric
# Out:
# C:\Users\Tom Hank\AppData\Local\Temp\ipykernel_5328\4080616638.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['price'] = data['price'].str.replace('$', '').str.replace(',', '').astype(float)  # Convert price to numeric

# %% [markdown]
# ### Remove outliers

# %%
data = data[data['price'] <= 1000]  # Keep listings with price less than or equal to $1000

# %%
data.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   90676   https://www.airbnb.com/rooms/90676  20230328184402   2023-03-28
# 1  543140  https://www.airbnb.com/rooms/543140  20230328184402   2023-03-28
# 2  591101  https://www.airbnb.com/rooms/591101  20230328184402   2023-03-28
# 3  923248  https://www.airbnb.com/rooms/923248  20230328184402   2023-03-28
# 4  927867  https://www.airbnb.com/rooms/927867  20230328184402   2023-03-28
#
#         source                                              name  \
# 0  city scrape                  Short North - Italianate Cottage
# 1  city scrape                Private queen bedroom 1 - N.Campus
# 2  city scrape                    Bellows Studio Loft  Apartment
# 3  city scrape  1 Single Bed in a Shared Coed Dorm at the Hostel
# 4  city scrape                   Full Private Room at the Hostel
#
#                                          description  \
# 0  Just steps from High Street and all the action...
# 1  Private, second-floor queen bed with desk, ple...
# 2  Famous American artist George Bellows home wit...
# 3  This is a shared dormitory room of up to 5 peo...
# 4  The Wayfaring Buckeye Hostel is a social place...
#
#                                neighborhood_overview  \
# 0  The Short North Italianate Cottage is located ...
# 1                   We are close to a lot of things!
# 2  A historic neighborhood of beautiful victorian...
# 3  We are located in the vibrant University Distr...
# 4  We are located in the vibrant University Distr...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/950e43cd-53f3...   483306  ...
# 1  https://a0.muscache.com/pictures/e720cdf0-e36b...  2350409  ...
# 2  https://a0.muscache.com/pictures/083ed5ee-7b8d...  2889677  ...
# 3  https://a0.muscache.com/pictures/29aabf51-4e6f...  4965048  ...
# 4  https://a0.muscache.com/pictures/08033ebe-286c...  4965048  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.88                   4.93                4.78
# 1                        4.89                   4.77                4.80
# 2                        4.91                   4.89                4.88
# 3                        4.89                   4.69                4.85
# 4                        4.90                   4.72                4.70
#
#      license instant_bookable calculated_host_listings_count  \
# 0  2022-2475                f                              3
# 1  2019-1344                f                              3
# 2  2019-1230                f                              1
# 3  2019-1314                f                              8
# 4  2019-1314                f                              8
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           3
# 1                                           0
# 2                                           0
# 3                                           2
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            3
# 2                                            1
# 3                                            4
# 4                                            4
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              4.64
# 1                                           0              0.96
# 2                                           0              2.16
# 3                                           2              2.49
# 4                                           2              0.59
#
# [5 rows x 75 columns]

# %% [markdown]
# ### Standardize columns

# %%
data['host_response_rate'] = data['host_response_rate'].str.rstrip('%').astype(float) / 100  # Convert response rate to decimal

# %%
data.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   90676   https://www.airbnb.com/rooms/90676  20230328184402   2023-03-28
# 1  543140  https://www.airbnb.com/rooms/543140  20230328184402   2023-03-28
# 2  591101  https://www.airbnb.com/rooms/591101  20230328184402   2023-03-28
# 3  923248  https://www.airbnb.com/rooms/923248  20230328184402   2023-03-28
# 4  927867  https://www.airbnb.com/rooms/927867  20230328184402   2023-03-28
#
#         source                                              name  \
# 0  city scrape                  Short North - Italianate Cottage
# 1  city scrape                Private queen bedroom 1 - N.Campus
# 2  city scrape                    Bellows Studio Loft  Apartment
# 3  city scrape  1 Single Bed in a Shared Coed Dorm at the Hostel
# 4  city scrape                   Full Private Room at the Hostel
#
#                                          description  \
# 0  Just steps from High Street and all the action...
# 1  Private, second-floor queen bed with desk, ple...
# 2  Famous American artist George Bellows home wit...
# 3  This is a shared dormitory room of up to 5 peo...
# 4  The Wayfaring Buckeye Hostel is a social place...
#
#                                neighborhood_overview  \
# 0  The Short North Italianate Cottage is located ...
# 1                   We are close to a lot of things!
# 2  A historic neighborhood of beautiful victorian...
# 3  We are located in the vibrant University Distr...
# 4  We are located in the vibrant University Distr...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/950e43cd-53f3...   483306  ...
# 1  https://a0.muscache.com/pictures/e720cdf0-e36b...  2350409  ...
# 2  https://a0.muscache.com/pictures/083ed5ee-7b8d...  2889677  ...
# 3  https://a0.muscache.com/pictures/29aabf51-4e6f...  4965048  ...
# 4  https://a0.muscache.com/pictures/08033ebe-286c...  4965048  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.88                   4.93                4.78
# 1                        4.89                   4.77                4.80
# 2                        4.91                   4.89                4.88
# 3                        4.89                   4.69                4.85
# 4                        4.90                   4.72                4.70
#
#      license instant_bookable calculated_host_listings_count  \
# 0  2022-2475                f                              3
# 1  2019-1344                f                              3
# 2  2019-1230                f                              1
# 3  2019-1314                f                              8
# 4  2019-1314                f                              8
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            3
# 1                                            0
# 2                                            0
# 3                                            2
# 4                                            2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            3
# 2                                            1
# 3                                            4
# 4                                            4
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              4.64
# 1                                           0              0.96
# 2                                           0              2.16
# 3                                           2              2.49
# 4                                           2              0.59
#
# [5 rows x 75 columns]

# %% [markdown]
# ### Clean text data

# %%
data['description'] = data['description'].str.lower()  # Convert description to lowercase

# %%
data.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   90676   https://www.airbnb.com/rooms/90676  20230328184402   2023-03-28
# 1  543140  https://www.airbnb.com/rooms/543140  20230328184402   2023-03-28
# 2  591101  https://www.airbnb.com/rooms/591101  20230328184402   2023-03-28
# 3  923248  https://www.airbnb.com/rooms/923248  20230328184402   2023-03-28
# 4  927867  https://www.airbnb.com/rooms/927867  20230328184402   2023-03-28
#
#         source                                              name  \
# 0  city scrape                  Short North - Italianate Cottage
# 1  city scrape                Private queen bedroom 1 - N.Campus
# 2  city scrape                    Bellows Studio Loft  Apartment
# 3  city scrape  1 Single Bed in a Shared Coed Dorm at the Hostel
# 4  city scrape                   Full Private Room at the Hostel
#
#                                          description  \
# 0  just steps from high street and all the action...
# 1  private, second-floor queen bed with desk, ple...
# 2  famous american artist george bellows home wit...
# 3  this is a shared dormitory room of up to 5 peo...
# 4  the wayfaring buckeye hostel is a social place...
#
#                                neighborhood_overview  \
# 0  The Short North Italianate Cottage is located ...
# 1                   We are close to a lot of things!
# 2  A historic neighborhood of beautiful victorian...
# 3  We are located in the vibrant University Distr...
# 4  We are located in the vibrant University Distr...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/950e43cd-53f3...   483306  ...
# 1  https://a0.muscache.com/pictures/e720cdf0-e36b...  2350409  ...
# 2  https://a0.muscache.com/pictures/083ed5ee-7b8d...  2889677  ...
# 3  https://a0.muscache.com/pictures/29aabf51-4e6f...  4965048  ...
# 4  https://a0.muscache.com/pictures/08033ebe-286c...  4965048  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.88                   4.93                4.78
# 1                        4.89                   4.77                4.80
# 2                        4.91                   4.89                4.88
# 3                        4.89                   4.69                4.85
# 4                        4.90                   4.72                4.70
#
#      license instant_bookable calculated_host_listings_count  \
# 0  2022-2475                f                              3
# 1  2019-1344                f                              3
# 2  2019-1230                f                              1
# 3  2019-1314                f                              8
# 4  2019-1314                f                              8
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            3
# 1                                            0
# 2                                            0
# 3                                            2
# 4                                            2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            3
# 2                                            1
# 3                                            4
# 4                                            4
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              4.64
# 1                                           0              0.96
# 2                                           0              2.16
# 3                                           2              2.49
# 4                                           2              0.59
#
# [5 rows x 75 columns]

# %%
data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
data.describe()
# Out:
#                  id     scrape_id       host_id  host_response_rate  \
# count  2.341000e+03  2.341000e+03  2.341000e+03         2216.000000
# mean   3.759875e+17  2.023033e+13  2.034103e+08            0.986625
# std    3.638235e+17  1.238546e+00  1.577686e+08            0.069749
# min    9.067600e+04  2.023033e+13  7.876100e+04            0.000000
# 25%    4.431677e+07  2.023033e+13  5.926323e+07            1.000000
# 50%    5.644468e+17  2.023033e+13  1.584396e+08            1.000000
# 75%    7.268476e+17  2.023033e+13  3.259330e+08            1.000000
# max    8.567594e+17  2.023033e+13  5.060952e+08            1.000000
#
#        host_listings_count  host_total_listings_count  \
# count          2341.000000                2341.000000
# mean             74.044425                 103.041008
# std             394.902523                 549.523935
# min               1.000000                   1.000000
# 25%               2.000000                   3.000000
# 50%               7.000000                   8.000000
# 75%              25.000000                  30.000000
# max            3303.000000                4535.000000
#
#        neighbourhood_group_cleansed     latitude    longitude  accommodates  \
# count                           0.0  2341.000000  2341.000000   2341.000000
# mean                            NaN    39.983172   -82.990244      5.028193
# std                             NaN     0.040432     0.039825      3.205107
# min                             NaN    39.861210   -83.146800      1.000000
# 25%                             NaN    39.956220   -83.007730      2.000000
# 50%                             NaN    39.978850   -82.997470      4.000000
# 75%                             NaN    39.996660   -82.974822      6.000000
# max                             NaN    40.152417   -82.779340     16.000000
#
#        ...  review_scores_cleanliness  review_scores_checkin  \
# count  ...                2050.000000            2050.000000
# mean   ...                   4.777185               4.883571
# std    ...                   0.347013               0.233870
# min    ...                   1.000000               1.000000
# 25%    ...                   4.710000               4.870000
# 50%    ...                   4.890000               4.960000
# 75%    ...                   5.000000               5.000000
# max    ...                   5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                  2050.000000             2050.000000
# mean                      4.886312                4.737937
# std                       0.249507                0.362511
# min                       1.000000                1.000000
# 25%                       4.870000                4.670000
# 50%                       4.970000                4.860000
# 75%                       5.000000                4.970000
# max                       5.000000                5.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count          2050.000000                     2341.000000
# mean              4.736815                       15.098249
# std               0.346440                       21.824332
# min               1.000000                        1.000000
# 25%               4.670000                        2.000000
# 50%               4.830000                        5.000000
# 75%               4.930000                       21.000000
# max               5.000000                       97.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  2341.000000
# mean                                     13.387868
# std                                      21.608460
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       3.000000
# 75%                                      19.000000
# max                                      97.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   2341.000000
# mean                                       1.639043
# std                                        5.742256
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       36.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  2341.000000        2050.000000
# mean                                      0.011534           2.530820
# std                                       0.135067           2.030628
# min                                       0.000000           0.020000
# 25%                                       0.000000           1.000000
# 50%                                       0.000000           2.050000
# 75%                                       0.000000           3.570000
# max                                       2.000000          12.880000
#
# [8 rows x 42 columns]

# %% [markdown]
# ### Save the cleaned data to a new CSV file

# %%
data.to_csv('cleaned_airbnb_data.csv', index=False)
